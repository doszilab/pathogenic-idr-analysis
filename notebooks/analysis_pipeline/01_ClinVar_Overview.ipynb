# %%
# Setup environment to import from src
import sys
import os
import matplotlib.pyplot as plt

# Add the project root to the system path
sys.path.append(os.path.abspath('../..'))

# Import specific modules
from src.clinvar import stats
from src.clinvar import ontology
from src.clinvar import functional

# Configure matplotlib for inline plotting
# %matplotlib inline

# %%
# Generate Figure 1: Structural Classification of Variants
# This function loads the data, filters for main isoforms, and creates the plot.
figures_1 = stats.generate_figure_1()

for fig in figures_1:
    fig.show()
# Out:
# Filtering main isoforms...
# Generating Figure 1a (Proteome & Variants)...
# Generating Figure 1b (Structure)...
# Generating Figure 1c (Positional Split - Disease Weighted)...
# Generating Figure 1d (Gene Split)...
# Done.

# %%
# --- Cell: Generate Figure 2 ---
# This function generates panels 2A, 2B, 2C, and 2D, and saves them to the output directory.
figures_2 = ontology.generate_figure_2()

# Display figures in the notebook
for fig in figures_2:
    fig.show()
# Out:
# Loading data for Figure 2...
# Loading /dlab/home/norbi/paper_projects/pathogenic-idr-analysis/data/processed/clinvar_positional_disorder.tsv...
# Loading /dlab/home/norbi/paper_projects/pathogenic-idr-analysis/data/processed/clinvar_positional_order.tsv...
# Generating Fig 2a (Left)...
# Generating Fig 2a (Right)...
# Generating Fig 2c...
# /dlab/home/norbi/paper_projects/pathogenic-idr-analysis/src/clinvar/ontology.py:77: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   heatmap_data = pd.DataFrame(index=unique_categories, columns=genic_categories).fillna(0)
# Generating Fig 2d (Genes)...
# ...

# %%
# Generate Figure 3: Functional Annotation Landscape
figures_3 = functional.generate_figure_3()

# Display
for fig in figures_3:
    fig.show()
# Out:
# Loading data for Functional Analysis...
# Generating Fig 3a (PDB Coverage)...
# Generating Fig 3b (Functional Donuts)...
# Generating Fig 3c (Functional Types)...
# Generating Fig 3d (PTM Distribution)...
# Generating Supp Fig 1c (Top ROI)...
# Generating Supp Fig 1d (Benign Rates)...
# Functional Analysis Figures saved to /dlab/home/norbi/paper_projects/pathogenic-idr-analysis/output/figures
